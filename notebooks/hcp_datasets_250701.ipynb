# %% [markdown]
# ### Datasets updates July 2025 ###

# %%
import os
import pandas as pd
import numpy as np
import logging

logger = logging.getLogger(__name__)

# Import this module with autoreload
# %load_ext autoreload
# %autoreload 2
import llmt

# %%
# Files and directories
data_dir = os.path.join(os.environ.get('DATA'), 'hcp')

# Updated training set
trainset_file_name = 'cleaned_testing_set.xlsx'

# Old data set with training data
hcp_dataset_file_name = 'hcp-alldata-250413.parquet'

# %%
# Load the new training data
df_train_raw = pd.read_excel(os.path.join(data_dir, trainset_file_name))

# Let's get rid of the old columns
df_train = df_train_raw.\
    drop(['mental_health_ref', 'inpatient_ref', 'outpatient_ref'], axis=1).\
    rename(columns={'mental_health_ref_cleaned': 'mental_health',
                    'inpatient_ref_cleaned': 'inpatient',
                    'outpatient_ref_cleaned': 'outpatient'}).\
    assign(dset='train').reset_index(drop=True)

display(df_train.head())
print(df_train.shape)
print(len(df_train['id'].unique()))
# Out:
#           id                                               name  \
# 0  491639-77  144-Bed Hospital Facility Joint Venture in Den...
# 1   10995-58                      Acadia Healthcare (NAS: ACHC)
# 2  431643-07                                             Actriv
# 3  310749-31                                              Alima
# 4  107240-50                         Alvarado Parkway Institute
#
#                                          description  mental_health  \
# 0  Provider of behavioral health services located...              1
# 1  Acadia Healthcare Co Inc acquires and develops...              1
# 2  Provider of healthcare staffing services based...              1
# 3  Operator of a non-governmental organization in...              0
# 4  Operator of a psychiatric health care facility...              1
#
#    inpatient  outpatient   dset
# 0          1           1  train
# 1          1           1  train
# 2          0           0  train
# 3          0           0  train
# 4          1           1  train
# (187, 7)
# 187

# %%
# Open the old data sets
df_test_raw = pd.read_parquet(os.path.join(data_dir, hcp_dataset_file_name))
print(df_test_raw.shape)
print(len(df_test_raw['id'].unique()))

# Remove the training data
df_test = df_test_raw.loc[~df_test_raw['id'].isin(df_train['id'].unique())].\
                reset_index(drop=True)
display(df_test.head())
print(df_test.shape)
print(len(df_test['id'].unique()))
# Out:
# (2025, 7)
# 2025
#           id                             name  \
# 0  525519-64                     10-4 Medical
# 1  111309-13                    12 Keys Rehab
# 2  107097-94                   1321 Investors
# 3  167073-22              180 Health Partners
# 4  224481-61  181st Street Urgent Care Center
#
#                                          description  mental_health  \
# 0  Provider focused on whole-person healthcare in...            NaN
# 1  Provider of rehabilitation services intended t...            NaN
# 2  Provider of healthcare services. The company o...            NaN
# 3  Provider of healthcare support services intend...            NaN
# 4  Provider of medical services intended to treat...            NaN
#
#    inpatient  outpatient  dset
# 0        NaN         NaN  test
# 1        NaN         NaN  test
# 2        NaN         NaN  test
# 3        NaN         NaN  test
# 4        NaN         NaN  test
# (1838, 7)
# 1838

# %%
# Save the data sets
train_set_name = 'hcp-train-250701.parquet'
test_set_name = 'hcp-test-250701.parquet'
df_train.to_parquet(os.path.join(data_dir, train_set_name))
df_test.to_parquet(os.path.join(data_dir, test_set_name))
